# %%
import pandas as pd
import missingno as missda

# %%
data = pd.read_csv('pricing.csv')
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data.drop(columns=[
    "KitchenQual", "GarageArea", "LotFrontage", "LotArea", "MSSubClass", 
    "Alley", "RoofMatl", "Functional", "Fireplaces", "BsmtFinSF1", 
    "BsmtFinType2", "BsmtFinSF2", "BsmtUnfSF", "TotalBsmtSF", "FireplaceQu", 
    "GarageType", "GarageYrBlt", "GarageFinish", "Exterior1st", "Exterior2nd", 
    "MasVnrType", "MasVnrArea", "ExterQual", "LandContour", "LotConfig", 
    "LandSlope", "Neighborhood", "Condition1", "Condition2", "HouseStyle", 
    "PoolQC", "Fence", "MiscFeature", "MiscVal", "MoSold", "YrSold", 
    "SaleType", "SaleCondition", "BsmtQual", "BsmtCond", "BsmtExposure", 
    "GrLivArea", "BsmtFullBath", "BsmtHalfBath", "FullBath", "HalfBath",'Street',
    "RoofStyle", "PavedDrive", "WoodDeckSF", "OpenPorchSF", "EnclosedPorch", 
    "3SsnPorch", "ScreenPorch", "Electrical", "Heating", "Foundation",'Id',
    "BsmtFinType1", "LotShape", "ExterCond", "HeatingQC", "BldgType",'MSZoning'
],inplace=True)

# %%
missda.bar(data)
# Out:
# <Axes: >

# %%
data.rename(columns={'1stFlrSF' : 'fstFlrSF','2ndFlrSF':'secFlrSF'},inplace=True)
data.head()
# Out:
#   Utilities  OverallQual  OverallCond  YearBuilt  YearRemodAdd CentralAir  \
# 0    AllPub            7            5       2003          2003          Y
# 1    AllPub            6            8       1976          1976          Y
# 2    AllPub            7            5       2001          2002          Y
# 3    AllPub            7            5       1915          1970          Y
# 4    AllPub            8            5       2000          2000          Y
#
#    fstFlrSF  secFlrSF  LowQualFinSF  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0       856       854             0             3             1             8
# 1      1262         0             0             3             1             6
# 2       920       866             0             3             1             6
# 3       961       756             0             3             1             7
# 4      1145      1053             0             4             1             9
#
# ...

# %%
data['Total_area'] = data['fstFlrSF'] + data['secFlrSF']
data.head()
# Out:
#   Utilities  OverallQual  OverallCond  YearBuilt  YearRemodAdd CentralAir  \
# 0    AllPub            7            5       2003          2003          Y
# 1    AllPub            6            8       1976          1976          Y
# 2    AllPub            7            5       2001          2002          Y
# 3    AllPub            7            5       1915          1970          Y
# 4    AllPub            8            5       2000          2000          Y
#
#    fstFlrSF  secFlrSF  LowQualFinSF  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0       856       854             0             3             1             8
# 1      1262         0             0             3             1             6
# 2       920       866             0             3             1             6
# 3       961       756             0             3             1             7
# 4      1145      1053             0             4             1             9
#
# ...

# %%
has_2nd_floor = data.loc[data.secFlrSF > 0]
has_2nd_floor
# Out:
#      Utilities  OverallQual  OverallCond  YearBuilt  YearRemodAdd CentralAir  \
# 0       AllPub            7            5       2003          2003          Y
# 2       AllPub            7            5       2001          2002          Y
# 3       AllPub            7            5       1915          1970          Y
# 4       AllPub            8            5       2000          2000          Y
# 5       AllPub            5            5       1993          1995          Y
# ...        ...          ...          ...        ...           ...        ...
# 1447    AllPub            8            5       1995          1996          Y
# 1448    AllPub            4            7       1910          2000          N
# 1450    AllPub            5            5       1974          1974          Y
# 1455    AllPub            6            5       1999          2000          Y
# 1457    AllPub            7            9       1941          2006          Y
#
# ...

# %%
remodeled = data.loc[data.YearRemodAdd != data.YearBuilt]
remodeled
# Out:
#      Utilities  OverallQual  OverallCond  YearBuilt  YearRemodAdd CentralAir  \
# 2       AllPub            7            5       2001          2002          Y
# 3       AllPub            7            5       1915          1970          Y
# 5       AllPub            5            5       1993          1995          Y
# 6       AllPub            8            5       2004          2005          Y
# 8       AllPub            7            5       1931          1950          Y
# ...        ...          ...          ...        ...           ...        ...
# 1454    AllPub            7            5       2004          2005          Y
# 1455    AllPub            6            5       1999          2000          Y
# 1456    AllPub            6            6       1978          1988          Y
# 1457    AllPub            7            9       1941          2006          Y
# 1458    AllPub            5            6       1950          1996          Y
#
# ...

# %%
has_pool = data.loc[data.PoolArea>0]
has_pool
# Out:
#      Utilities  OverallQual  OverallCond  YearBuilt  YearRemodAdd CentralAir  \
# 197     AllPub            8            4       1918          1990          Y
# 810     AllPub            6            6       1974          1999          Y
# 1170    AllPub            6            6       1977          1977          Y
# 1182    AllPub           10            5       1996          1996          Y
# 1298    AllPub           10            5       2008          2008          Y
# 1386    AllPub            7            5       1978          1978          Y
# 1423    AllPub            6            7       1966          1966          Y
#
#       fstFlrSF  secFlrSF  LowQualFinSF  BedroomAbvGr  KitchenAbvGr  \
# 197       1360      1360           392             4             1
# 810       1309         0             0             3             1
# 1170      1118         0             0             3             1
# 1182      2411      2065             0             4             1
# ...

# %%
data.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
data.loc[data.SalePrice ==755000.000000]
# Out:
#     Utilities  OverallQual  OverallCond  YearBuilt  YearRemodAdd CentralAir  \
# 691    AllPub           10            6       1994          1995          Y
#
#      fstFlrSF  secFlrSF  LowQualFinSF  BedroomAbvGr  KitchenAbvGr  \
# 691      2444      1872             0             4             1
#
#      TotRmsAbvGrd  GarageCars GarageQual GarageCond  PoolArea  SalePrice  \
# 691            10           3         TA         TA         0     755000
#
#      Total_area
# 691        4316

# %% [markdown]
# data with outliers:
# secFlrSF:has many zeros but can be logical as not all houses has 2nd floor
# LowQualFinSF
# PoolArea:has many zeros but can be logical as not all houses has Pool

# %%
data.describe()
# Out:
#        OverallQual  OverallCond    YearBuilt  YearRemodAdd     fstFlrSF  \
# count  1460.000000  1460.000000  1460.000000   1460.000000  1460.000000
# mean      6.099315     5.575342  1971.267808   1984.865753  1162.626712
# std       1.382997     1.112799    30.202904     20.645407   386.587738
# min       1.000000     1.000000  1872.000000   1950.000000   334.000000
# 25%       5.000000     5.000000  1954.000000   1967.000000   882.000000
# 50%       6.000000     5.000000  1973.000000   1994.000000  1087.000000
# 75%       7.000000     6.000000  2000.000000   2004.000000  1391.250000
# max      10.000000     9.000000  2010.000000   2010.000000  4692.000000
#
#           secFlrSF  LowQualFinSF  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# count  1460.000000   1460.000000   1460.000000   1460.000000   1460.000000
# mean    346.992466      5.844521      2.866438      1.046575      6.517808
# std     436.528436     48.623081      0.815778      0.220338      1.625393
# ...
